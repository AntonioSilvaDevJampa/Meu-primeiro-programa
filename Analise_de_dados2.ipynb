# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioSilvaDevJampa/Meu-primeiro-programa/blob/main/Analise_de_dados2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparando para nova analise de dados importando as bibliotecas necessarias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Criar um código para aumentar a barra de rolagem para visualizar menhor o dataframe

# %%
pd.set_option('display.max_columns' , 500)
pd.set_option('display.max_rows' , 1000)

# %% [markdown]
# # Importar o arquivo para analise

# %%
df1 = pd.read_csv('ds_salaries.csv')

# %% [markdown]
# # Verificar o head do dataframe

# %%
df1.head(10)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
# 5       2023               SE              FT         Applied Scientist
# 6       2023               SE              FT         Applied Scientist
# 7       2023               SE              FT            Data Scientist
# 8       2023               SE              FT            Data Scientist
# 9       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# ...

# %% [markdown]
# # Visualizar o tail do datrafame

# %%
df1.tail(10)
# Out:
#       work_year experience_level employment_type  \
# 3745       2021               SE              FT
# 3746       2021               MI              FT
# 3747       2021               MI              FT
# 3748       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
# 3753       2020               EN              CT
# 3754       2021               SE              FT
#
#                                job_title   salary salary_currency  \
# 3745            Director of Data Science   168000             USD
# 3746                      Data Scientist   160000             SGD
# 3747  Applied Machine Learning Scientist   423000             USD
# 3748                       Data Engineer    24000             EUR
# 3749                     Data Specialist   165000             USD
# ...

# %% [markdown]
# # Usar o shape para determinar o número de colunas e linhas do datafame

# %%
df1.shape
# Out:
# (3755, 11)

# %% [markdown]
# # Printar o arquivo para verificar o dataframe

# %%
print(df1)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# # Printar as informações do dataframe usando o comando info para ver os tipos de dados

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB
# None

# %% [markdown]
# # Verificar se existe algum valor nulo no dataframe

# %%
df1.isna().any()
# Out:
# work_year             False
# experience_level      False
# employment_type       False
# job_title             False
# salary                False
# salary_currency       False
# salary_in_usd         False
# employee_residence    False
# remote_ratio          False
# company_location      False
# company_size          False
# dtype: bool

# %% [markdown]
# # Usar o display para observar o dataframe

# %%
display(df1)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# # Vou renomear as colunas para português

# %%
df1.rename(columns={"work_year":"Ano_Pagamento","experience_level":"Nível_Experiência","employment_type":"Tipo_Emprego","job_title":"Função_Emprego","salary":"Salário","salary_currency":"salário_moeda","salary_in_usd":"Salário_em_USD","employee_residence":"Residência_Funcionário","remote_ratio":"Trabalho_Remoto","company_location":"Sede_Empresa","company_size":"Tamanho_Empresa"}, inplace= True)

# %% [markdown]
# # Usar o display para observar a alteração do dataframe

# %%
display(df1)
# Out:
#       Ano_Pagamento Nível_Experiência Tipo_Emprego            Função_Emprego  \
# 0              2023                SE           FT  Principal Data Scientist
# 1              2023                MI           CT               ML Engineer
# 2              2023                MI           CT               ML Engineer
# 3              2023                SE           FT            Data Scientist
# 4              2023                SE           FT            Data Scientist
# ...             ...               ...          ...                       ...
# 3750           2020                SE           FT            Data Scientist
# 3751           2021                MI           FT  Principal Data Scientist
# 3752           2020                EN           FT            Data Scientist
# 3753           2020                EN           CT     Business Data Analyst
# 3754           2021                SE           FT      Data Science Manager
#
# ...

# %% [markdown]
# # Utilizar o describe para observar a estatistica geral do dataframe

# %%
df1.describe()
# Out:
#        Ano_Pagamento       Salário  Salário_em_USD  Trabalho_Remoto
# count    3755.000000  3.755000e+03     3755.000000      3755.000000
# mean     2022.373635  1.906956e+05   137570.389880        46.271638
# std         0.691448  6.716765e+05    63055.625278        48.589050
# min      2020.000000  6.000000e+03     5132.000000         0.000000
# 25%      2022.000000  1.000000e+05    95000.000000         0.000000
# 50%      2022.000000  1.380000e+05   135000.000000         0.000000
# 75%      2023.000000  1.800000e+05   175000.000000       100.000000
# max      2023.000000  3.040000e+07   450000.000000       100.000000

# %% [markdown]
# # Dividirei os dados pelos anos trabalhados para determinar os valores pagos de forma estatistica de acordo com o ano trabalhado

# %%
df1['Ano_Pagamento'] == 2020
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3750     True
# 3751    False
# 3752     True
# 3753     True
# 3754    False
# Name: Ano_Pagamento, Length: 3755, dtype: bool

# %% [markdown]
# # Primeiro vamos observar o ano de 2020

# %%
Ano_2020 = df1['Ano_Pagamento'] == 2020

# %%
df1[Ano_2020]
# Out:
#       Ano_Pagamento Nível_Experiência Tipo_Emprego  \
# 183            2020                EX           FT
# 2118           2020                MI           FT
# 3119           2020                EN           FT
# 3120           2020                EN           FT
# 3138           2020                EN           FT
# 3163           2020                EN           FT
# 3419           2020                SE           FT
# 3446           2020                EN           FT
# 3455           2020                MI           FT
# 3506           2020                MI           FT
# 3514           2020                EN           FT
# 3517           2020                SE           FT
# 3522           2020                MI           FT
# 3523           2020                MI           FT
# 3524           2020                MI           FT
# 3530           2020                MI           FT
# 3545           2020                EN           FT
# ...

# %%
df1[Ano_2020].shape
# Out:
# (76, 11)
