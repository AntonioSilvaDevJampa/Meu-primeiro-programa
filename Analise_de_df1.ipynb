# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioSilvaDevJampa/Meu-primeiro-programa/blob/main/Analise_de_df1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analise de dataframe com pandas

# %% [markdown]
# # primeiro importar o pandas para analisar os dados

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # importar o arquivo para analise

# %%
df1 = pd.read_csv('owid-co2-data.csv')

# %% [markdown]
# # Printar o arquivo para verificar o dataframe

# %%
print(df1)
# Out:
#       iso_code      country  year    co2  co2_per_capita  trade_co2  \
# 0          AFG  Afghanistan  1949  0.015           0.002        NaN
# 1          AFG  Afghanistan  1950  0.084           0.011        NaN
# 2          AFG  Afghanistan  1951  0.092           0.012        NaN
# 3          AFG  Afghanistan  1952  0.092           0.012        NaN
# 4          AFG  Afghanistan  1953  0.106           0.013        NaN
# ...        ...          ...   ...    ...             ...        ...
# 14994      MUS    Mauritius  2005  3.294           2.696      1.298
# 14995      MUS    Mauritius  2006  3.627           2.954      1.553
# 14996      MUS    Mauritius  2007  3.686           2.987      1.244
# 14997      MUS    Mauritius  2008  3.767           3.039      1.558
# 14998      MUS    Mauritius  2009  3.708           2.981      1.335
#
#        cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 0             NaN                    NaN     0.015                0.002  ...
# 1             NaN                    NaN     0.021                0.003  ...
# 2             NaN                    NaN     0.026                0.003  ...
# 3             NaN                    NaN     0.032                0.004  ...
# 4             NaN                    NaN     0.038                0.005  ...
# ...           ...                    ...       ...                  ...  ...
# 14994         NaN                    NaN     0.851                0.696  ...
# 14995         NaN                    NaN     1.136                0.925  ...
# 14996         NaN                    NaN     1.323                1.072  ...
# 14997         NaN                    NaN     1.543                1.245  ...
# 14998         NaN                    NaN     1.411                1.134  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 0                                NaN      NaN                 NaN
# 1                                NaN      NaN                 NaN
# 2                                NaN      NaN                 NaN
# 3                                NaN      NaN                 NaN
# 4                                NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 14994                          3.953     1.51               1.236
# 14995                          4.283     1.59               1.295
# 14996                          4.376     1.62               1.313
# 14997                          4.446     1.64               1.323
# 14998                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita  population           gdp  \
# 0                NaN                       NaN   7624058.0           NaN
# 1                NaN                       NaN   7752117.0  9.421400e+09
# 2                NaN                       NaN   7840151.0  9.692280e+09
# 3                NaN                       NaN   7935996.0  1.001733e+10
# 4                NaN                       NaN   8039684.0  1.063052e+10
# ...              ...                       ...         ...           ...
# 14994           0.26                     0.213   1222010.0  1.830074e+10
# 14995           0.25                     0.204   1228089.0  1.885470e+10
# 14996           0.26                     0.211   1233890.0  1.961498e+10
# 14997           0.25                     0.202   1239262.0  2.033346e+10
# 14998            NaN                       NaN         NaN           NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                             NaN                NaN             NaN
# 1                             NaN                NaN             NaN
# 2                             NaN                NaN             NaN
# 3                             NaN                NaN             NaN
# 4                             NaN                NaN             NaN
# ...                           ...                ...             ...
# 14994                      18.180          14877.295           0.993
# 14995                      18.978          15452.885           1.007
# 14996                      19.697          15963.221           1.004
# 14997                      20.270          16356.546           0.997
# 14998                         NaN                NaN             NaN
#
# [14999 rows x 60 columns]

# %% [markdown]
# # Printar as informações do dataframe usando o comando info

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 60 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   iso_code                             12257 non-null  object
#  1   country                              14999 non-null  object
#  2   year                                 14999 non-null  int64
#  3   co2                                  14177 non-null  float64
#  4   co2_per_capita                       13755 non-null  float64
#  5   trade_co2                            2360 non-null   float64
#  6   cement_co2                           7130 non-null   float64
#  7   cement_co2_per_capita                7108 non-null   float64
#  8   coal_co2                             10106 non-null  float64
#  9   coal_co2_per_capita                  9863 non-null   float64
#  10  flaring_co2                          2793 non-null   float64
#  11  flaring_co2_per_capita               2792 non-null   float64
#  12  gas_co2                              5476 non-null   float64
#  13  gas_co2_per_capita                   5476 non-null   float64
#  14  oil_co2                              12207 non-null  float64
#  15  oil_co2_per_capita                   11996 non-null  float64
#  16  other_industry_co2                   1262 non-null   float64
#  17  other_co2_per_capita                 1262 non-null   float64
#  18  co2_growth_prct                      14825 non-null  float64
#  19  co2_growth_abs                       13954 non-null  float64
#  20  co2_per_gdp                          9427 non-null   float64
#  21  co2_per_unit_energy                  5785 non-null   float64
#  22  consumption_co2                      2359 non-null   float64
#  23  consumption_co2_per_capita           2359 non-null   float64
#  24  consumption_co2_per_gdp              2252 non-null   float64
#  25  cumulative_co2                       14176 non-null  float64
#  26  cumulative_cement_co2                7130 non-null   float64
#  27  cumulative_coal_co2                  10105 non-null  float64
#  28  cumulative_flaring_co2               2793 non-null   float64
#  29  cumulative_gas_co2                   5476 non-null   float64
#  30  cumulative_oil_co2                   12206 non-null  float64
#  31  cumulative_other_co2                 1262 non-null   float64
#  32  trade_co2_share                      2359 non-null   float64
#  33  share_global_co2                     14176 non-null  float64
#  34  share_global_cement_co2              7130 non-null   float64
#  35  share_global_coal_co2                10105 non-null  float64
#  36  share_global_flaring_co2             2793 non-null   float64
#  37  share_global_gas_co2                 5476 non-null   float64
#  38  share_global_oil_co2                 12206 non-null  float64
#  39  share_global_other_co2               1262 non-null   float64
#  40  share_global_cumulative_co2          14176 non-null  float64
#  41  share_global_cumulative_cement_co2   7130 non-null   float64
#  42  share_global_cumulative_coal_co2     10105 non-null  float64
#  43  share_global_cumulative_flaring_co2  2793 non-null   float64
#  44  share_global_cumulative_gas_co2      5476 non-null   float64
#  45  share_global_cumulative_oil_co2      12206 non-null  float64
#  46  share_global_cumulative_other_co2    1262 non-null   float64
#  47  total_ghg                            3208 non-null   float64
#  48  ghg_per_capita                       3208 non-null   float64
#  49  total_ghg_excluding_lucf             3208 non-null   float64
#  50  ghg_excluding_lucf_per_capita        3208 non-null   float64
#  51  methane                              3209 non-null   float64
#  52  methane_per_capita                   3209 non-null   float64
#  53  nitrous_oxide                        3209 non-null   float64
#  54  nitrous_oxide_per_capita             3209 non-null   float64
#  55  population                           12687 non-null  float64
#  56  gdp                                  7721 non-null   float64
#  57  primary_energy_consumption           5365 non-null   float64
#  58  energy_per_capita                    5320 non-null   float64
#  59  energy_per_gdp                       4150 non-null   float64
# dtypes: float64(57), int64(1), object(2)
# memory usage: 6.9+ MB
# None

# %% [markdown]
# # usar o df1.isna().any() para saber se tem elementos vazios, no caso de ter será rerpresentado pelo boleano True , se não será representado pelo boleano False.

# %%
df1.isna().any()
# Out:
# iso_code                                True
# country                                False
# year                                   False
# co2                                     True
# co2_per_capita                          True
# trade_co2                               True
# cement_co2                              True
# cement_co2_per_capita                   True
# coal_co2                                True
# coal_co2_per_capita                     True
# flaring_co2                             True
# flaring_co2_per_capita                  True
# gas_co2                                 True
# gas_co2_per_capita                      True
# oil_co2                                 True
# oil_co2_per_capita                      True
# other_industry_co2                      True
# other_co2_per_capita                    True
# co2_growth_prct                         True
# co2_growth_abs                          True
# co2_per_gdp                             True
# co2_per_unit_energy                     True
# consumption_co2                         True
# consumption_co2_per_capita              True
# consumption_co2_per_gdp                 True
# cumulative_co2                          True
# cumulative_cement_co2                   True
# cumulative_coal_co2                     True
# cumulative_flaring_co2                  True
# cumulative_gas_co2                      True
# cumulative_oil_co2                      True
# cumulative_other_co2                    True
# trade_co2_share                         True
# share_global_co2                        True
# share_global_cement_co2                 True
# share_global_coal_co2                   True
# share_global_flaring_co2                True
# share_global_gas_co2                    True
# share_global_oil_co2                    True
# share_global_other_co2                  True
# share_global_cumulative_co2             True
# share_global_cumulative_cement_co2      True
# share_global_cumulative_coal_co2        True
# share_global_cumulative_flaring_co2     True
# share_global_cumulative_gas_co2         True
# share_global_cumulative_oil_co2         True
# share_global_cumulative_other_co2       True
# total_ghg                               True
# ghg_per_capita                          True
# total_ghg_excluding_lucf                True
# ghg_excluding_lucf_per_capita           True
# methane                                 True
# methane_per_capita                      True
# nitrous_oxide                           True
# nitrous_oxide_per_capita                True
# population                              True
# gdp                                     True
# primary_energy_consumption              True
# energy_per_capita                       True
# energy_per_gdp                          True
# dtype: bool

# %% [markdown]
# # Utilizar df1.isna().sum para determinar quantos dados Nan estão em cada coluna

# %%
df1.isna().sum()
# Out:
# iso_code                                2742
# country                                    0
# year                                       0
# co2                                      822
# co2_per_capita                          1244
# trade_co2                              12639
# cement_co2                              7869
# cement_co2_per_capita                   7891
# coal_co2                                4893
# coal_co2_per_capita                     5136
# flaring_co2                            12206
# flaring_co2_per_capita                 12207
# gas_co2                                 9523
# gas_co2_per_capita                      9523
# oil_co2                                 2792
# oil_co2_per_capita                      3003
# other_industry_co2                     13737
# other_co2_per_capita                   13737
# co2_growth_prct                          174
# co2_growth_abs                          1045
# co2_per_gdp                             5572
# co2_per_unit_energy                     9214
# consumption_co2                        12640
# consumption_co2_per_capita             12640
# consumption_co2_per_gdp                12747
# cumulative_co2                           823
# cumulative_cement_co2                   7869
# cumulative_coal_co2                     4894
# cumulative_flaring_co2                 12206
# cumulative_gas_co2                      9523
# cumulative_oil_co2                      2793
# cumulative_other_co2                   13737
# trade_co2_share                        12640
# share_global_co2                         823
# share_global_cement_co2                 7869
# share_global_coal_co2                   4894
# share_global_flaring_co2               12206
# share_global_gas_co2                    9523
# share_global_oil_co2                    2793
# share_global_other_co2                 13737
# share_global_cumulative_co2              823
# share_global_cumulative_cement_co2      7869
# share_global_cumulative_coal_co2        4894
# share_global_cumulative_flaring_co2    12206
# share_global_cumulative_gas_co2         9523
# share_global_cumulative_oil_co2         2793
# share_global_cumulative_other_co2      13737
# total_ghg                              11791
# ghg_per_capita                         11791
# total_ghg_excluding_lucf               11791
# ghg_excluding_lucf_per_capita          11791
# methane                                11790
# methane_per_capita                     11790
# nitrous_oxide                          11790
# nitrous_oxide_per_capita               11790
# population                              2312
# gdp                                     7278
# primary_energy_consumption              9634
# energy_per_capita                       9679
# energy_per_gdp                         10849
# dtype: int64

# %% [markdown]
# # Fazer o tratamento dos dados preenchendo onde existe dados faltantes Nan usando o comando fillna.

# %%
df1.mean()
# Out:
# <ipython-input-7-5652d058187b>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# year                                   1.951947e+03
# co2                                    3.075044e+02
# co2_per_capita                         3.773238e+00
# trade_co2                              2.134383e+00
# cement_co2                             1.605714e+01
# cement_co2_per_capita                  1.147254e-01
# coal_co2                               2.117222e+02
# coal_co2_per_capita                    1.539818e+00
# flaring_co2                            1.531234e+01
# flaring_co2_per_capita                 5.524631e-01
# gas_co2                                1.117605e+02
# gas_co2_per_capita                     1.078397e+00
# oil_co2                                1.169849e+02
# oil_co2_per_capita                     2.363299e+00
# other_industry_co2                     1.785719e+01
# other_co2_per_capita                   7.947147e-02
# co2_growth_prct                        1.697327e+01
# co2_growth_abs                         5.975054e+00
# co2_per_gdp                            4.209110e-01
# co2_per_unit_energy                    2.476686e-01
# consumption_co2                        8.945059e+02
# consumption_co2_per_capita             6.362443e+00
# consumption_co2_per_gdp                3.612012e-01
# cumulative_co2                         1.207124e+04
# cumulative_cement_co2                  3.890751e+02
# cumulative_coal_co2                    1.089906e+04
# cumulative_flaring_co2                 4.259864e+02
# cumulative_gas_co2                     2.473120e+03
# cumulative_oil_co2                     3.526169e+03
# cumulative_other_co2                   3.406316e+02
# trade_co2_share                        2.090226e+01
# share_global_co2                       6.371750e+00
# share_global_cement_co2                5.112504e+00
# share_global_coal_co2                  9.154916e+00
# share_global_flaring_co2               5.533018e+00
# share_global_gas_co2                   4.228061e+00
# share_global_oil_co2                   3.008151e+00
# share_global_other_co2                 1.491395e+01
# share_global_cumulative_co2            6.652988e+00
# share_global_cumulative_cement_co2     5.126833e+00
# share_global_cumulative_coal_co2       9.564357e+00
# share_global_cumulative_flaring_co2    4.780942e+00
# share_global_cumulative_gas_co2        3.764569e+00
# share_global_cumulative_oil_co2        2.962787e+00
# share_global_cumulative_other_co2      1.358899e+01
# total_ghg                              2.347374e+02
# ghg_per_capita                         7.945184e+00
# total_ghg_excluding_lucf               2.188268e+02
# ghg_excluding_lucf_per_capita          6.965232e+00
# methane                                4.165919e+01
# methane_per_capita                     2.108664e+00
# nitrous_oxide                          1.774026e+01
# nitrous_oxide_per_capita               6.251275e-01
# population                             6.368908e+07
# gdp                                    2.212016e+11
# primary_energy_consumption             9.156235e+02
# energy_per_capita                      2.277878e+04
# energy_per_gdp                         1.633573e+00
# dtype: float64

# %%
df1.columns
# Out:
# Index(['iso_code', 'country', 'year', 'co2', 'co2_per_capita', 'trade_co2',
#        'cement_co2', 'cement_co2_per_capita', 'coal_co2',
#        'coal_co2_per_capita', 'flaring_co2', 'flaring_co2_per_capita',
#        'gas_co2', 'gas_co2_per_capita', 'oil_co2', 'oil_co2_per_capita',
#        'other_industry_co2', 'other_co2_per_capita', 'co2_growth_prct',
#        'co2_growth_abs', 'co2_per_gdp', 'co2_per_unit_energy',
#        'consumption_co2', 'consumption_co2_per_capita',
#        'consumption_co2_per_gdp', 'cumulative_co2', 'cumulative_cement_co2',
#        'cumulative_coal_co2', 'cumulative_flaring_co2', 'cumulative_gas_co2',
#        'cumulative_oil_co2', 'cumulative_other_co2', 'trade_co2_share',
#        'share_global_co2', 'share_global_cement_co2', 'share_global_coal_co2',
#        'share_global_flaring_co2', 'share_global_gas_co2',
#        'share_global_oil_co2', 'share_global_other_co2',
#        'share_global_cumulative_co2', 'share_global_cumulative_cement_co2',
#        'share_global_cumulative_coal_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_gas_co2', 'share_global_cumulative_oil_co2',
#        'share_global_cumulative_other_co2', 'total_ghg', 'ghg_per_capita',
#        'total_ghg_excluding_lucf', 'ghg_excluding_lucf_per_capita', 'methane',
#        'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'population', 'gdp', 'primary_energy_consumption', 'energy_per_capita',
#        'energy_per_gdp'],
#       dtype='object')

# %% [markdown]
# # Criar um novo dataframe apenas das colunas numericas excluindo as colunas irrelevantes para utilizar a média para preencher com fillna

# %%
media = df1[[ 'year', 'co2', 'co2_per_capita', 'trade_co2',
       'cement_co2', 'cement_co2_per_capita', 'coal_co2',
       'coal_co2_per_capita', 'flaring_co2', 'flaring_co2_per_capita',
       'gas_co2', 'gas_co2_per_capita', 'oil_co2', 'oil_co2_per_capita',
       'other_industry_co2', 'other_co2_per_capita', 'co2_growth_prct',
       'co2_growth_abs', 'co2_per_gdp', 'co2_per_unit_energy',
       'consumption_co2', 'consumption_co2_per_capita',
       'consumption_co2_per_gdp', 'cumulative_co2', 'cumulative_cement_co2',
       'cumulative_coal_co2', 'cumulative_flaring_co2', 'cumulative_gas_co2',
       'cumulative_oil_co2', 'cumulative_other_co2', 'trade_co2_share',
       'share_global_co2', 'share_global_cement_co2', 'share_global_coal_co2',
       'share_global_flaring_co2', 'share_global_gas_co2',
       'share_global_oil_co2', 'share_global_other_co2',
       'share_global_cumulative_co2', 'share_global_cumulative_cement_co2',
       'share_global_cumulative_coal_co2',
       'share_global_cumulative_flaring_co2',
       'share_global_cumulative_gas_co2', 'share_global_cumulative_oil_co2',
       'share_global_cumulative_other_co2', 'total_ghg', 'ghg_per_capita',
       'total_ghg_excluding_lucf', 'ghg_excluding_lucf_per_capita', 'methane',
       'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
       'population', 'gdp', 'primary_energy_consumption', 'energy_per_capita',
       'energy_per_gdp']].mean()

# %%
df1[['year', 'co2', 'co2_per_capita', 'trade_co2',
       'cement_co2', 'cement_co2_per_capita', 'coal_co2',
       'coal_co2_per_capita', 'flaring_co2', 'flaring_co2_per_capita',
       'gas_co2', 'gas_co2_per_capita', 'oil_co2', 'oil_co2_per_capita',
       'other_industry_co2', 'other_co2_per_capita', 'co2_growth_prct',
       'co2_growth_abs', 'co2_per_gdp', 'co2_per_unit_energy',
       'consumption_co2', 'consumption_co2_per_capita',
       'consumption_co2_per_gdp', 'cumulative_co2', 'cumulative_cement_co2',
       'cumulative_coal_co2', 'cumulative_flaring_co2', 'cumulative_gas_co2',
       'cumulative_oil_co2', 'cumulative_other_co2', 'trade_co2_share',
       'share_global_co2', 'share_global_cement_co2', 'share_global_coal_co2',
       'share_global_flaring_co2', 'share_global_gas_co2',
       'share_global_oil_co2', 'share_global_other_co2',
       'share_global_cumulative_co2', 'share_global_cumulative_cement_co2',
       'share_global_cumulative_coal_co2',
       'share_global_cumulative_flaring_co2',
       'share_global_cumulative_gas_co2', 'share_global_cumulative_oil_co2',
       'share_global_cumulative_other_co2', 'total_ghg', 'ghg_per_capita',
       'total_ghg_excluding_lucf', 'ghg_excluding_lucf_per_capita', 'methane',
       'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
       'population', 'gdp', 'primary_energy_consumption', 'energy_per_capita',
       'energy_per_gdp']] = df1[['year','co2', 'co2_per_capita', 'trade_co2',
       'cement_co2', 'cement_co2_per_capita', 'coal_co2',
       'coal_co2_per_capita', 'flaring_co2', 'flaring_co2_per_capita',
       'gas_co2', 'gas_co2_per_capita', 'oil_co2', 'oil_co2_per_capita',
       'other_industry_co2', 'other_co2_per_capita', 'co2_growth_prct',
       'co2_growth_abs', 'co2_per_gdp', 'co2_per_unit_energy',
       'consumption_co2', 'consumption_co2_per_capita',
       'consumption_co2_per_gdp', 'cumulative_co2', 'cumulative_cement_co2',
       'cumulative_coal_co2', 'cumulative_flaring_co2', 'cumulative_gas_co2',
       'cumulative_oil_co2', 'cumulative_other_co2', 'trade_co2_share',
       'share_global_co2', 'share_global_cement_co2', 'share_global_coal_co2',
       'share_global_flaring_co2', 'share_global_gas_co2',
       'share_global_oil_co2', 'share_global_other_co2',
       'share_global_cumulative_co2', 'share_global_cumulative_cement_co2',
       'share_global_cumulative_coal_co2',
       'share_global_cumulative_flaring_co2',
       'share_global_cumulative_gas_co2', 'share_global_cumulative_oil_co2',
       'share_global_cumulative_other_co2', 'total_ghg', 'ghg_per_capita',
       'total_ghg_excluding_lucf', 'ghg_excluding_lucf_per_capita', 'methane',
       'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
       'population', 'gdp', 'primary_energy_consumption', 'energy_per_capita',
       'energy_per_gdp']].fillna(media)

# %%
display(df1)
# Out:
#       iso_code      country  year    co2  co2_per_capita  trade_co2  \
# 0          AFG  Afghanistan  1949  0.015           0.002   2.134383
# 1          AFG  Afghanistan  1950  0.084           0.011   2.134383
# 2          AFG  Afghanistan  1951  0.092           0.012   2.134383
# 3          AFG  Afghanistan  1952  0.092           0.012   2.134383
# 4          AFG  Afghanistan  1953  0.106           0.013   2.134383
# ...        ...          ...   ...    ...             ...        ...
# 14994      MUS    Mauritius  2005  3.294           2.696   1.298000
# 14995      MUS    Mauritius  2006  3.627           2.954   1.553000
# 14996      MUS    Mauritius  2007  3.686           2.987   1.244000
# 14997      MUS    Mauritius  2008  3.767           3.039   1.558000
# 14998      MUS    Mauritius  2009  3.708           2.981   1.335000
#
#        cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 0       16.057141               0.114725     0.015                0.002  ...
# 1       16.057141               0.114725     0.021                0.003  ...
# 2       16.057141               0.114725     0.026                0.003  ...
# 3       16.057141               0.114725     0.032                0.004  ...
# 4       16.057141               0.114725     0.038                0.005  ...
# ...           ...                    ...       ...                  ...  ...
# 14994   16.057141               0.114725     0.851                0.696  ...
# 14995   16.057141               0.114725     1.136                0.925  ...
# 14996   16.057141               0.114725     1.323                1.072  ...
# 14997   16.057141               0.114725     1.543                1.245  ...
# 14998   16.057141               0.114725     1.411                1.134  ...
#
#        ghg_excluding_lucf_per_capita    methane  methane_per_capita  \
# 0                           6.965232  41.659193            2.108664
# 1                           6.965232  41.659193            2.108664
# 2                           6.965232  41.659193            2.108664
# 3                           6.965232  41.659193            2.108664
# 4                           6.965232  41.659193            2.108664
# ...                              ...        ...                 ...
# 14994                       3.953000   1.510000            1.236000
# 14995                       4.283000   1.590000            1.295000
# 14996                       4.376000   1.620000            1.313000
# 14997                       4.446000   1.640000            1.323000
# 14998                       6.965232  41.659193            2.108664
#
#        nitrous_oxide  nitrous_oxide_per_capita    population           gdp  \
# 0          17.740256                  0.625127  7.624058e+06  2.212016e+11
# 1          17.740256                  0.625127  7.752117e+06  9.421400e+09
# 2          17.740256                  0.625127  7.840151e+06  9.692280e+09
# 3          17.740256                  0.625127  7.935996e+06  1.001733e+10
# 4          17.740256                  0.625127  8.039684e+06  1.063052e+10
# ...              ...                       ...           ...           ...
# 14994       0.260000                  0.213000  1.222010e+06  1.830074e+10
# 14995       0.250000                  0.204000  1.228089e+06  1.885470e+10
# 14996       0.260000                  0.211000  1.233890e+06  1.961498e+10
# 14997       0.250000                  0.202000  1.239262e+06  2.033346e+10
# 14998      17.740256                  0.625127  6.368908e+07  2.212016e+11
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                       915.62353       22778.777337        1.633573
# 1                       915.62353       22778.777337        1.633573
# 2                       915.62353       22778.777337        1.633573
# 3                       915.62353       22778.777337        1.633573
# 4                       915.62353       22778.777337        1.633573
# ...                           ...                ...             ...
# 14994                    18.18000       14877.295000        0.993000
# 14995                    18.97800       15452.885000        1.007000
# 14996                    19.69700       15963.221000        1.004000
# 14997                    20.27000       16356.546000        0.997000
# 14998                   915.62353       22778.777337        1.633573
#
# [14999 rows x 60 columns]

# %%
df1.isna().sum()
# Out:
# iso_code                               2742
# country                                   0
# year                                      0
# co2                                       0
# co2_per_capita                            0
# trade_co2                                 0
# cement_co2                                0
# cement_co2_per_capita                     0
# coal_co2                                  0
# coal_co2_per_capita                       0
# flaring_co2                               0
# flaring_co2_per_capita                    0
# gas_co2                                   0
# gas_co2_per_capita                        0
# oil_co2                                   0
# oil_co2_per_capita                        0
# other_industry_co2                        0
# other_co2_per_capita                      0
# co2_growth_prct                           0
# co2_growth_abs                            0
# co2_per_gdp                               0
# co2_per_unit_energy                       0
# consumption_co2                           0
# consumption_co2_per_capita                0
# consumption_co2_per_gdp                   0
# cumulative_co2                            0
# cumulative_cement_co2                     0
# cumulative_coal_co2                       0
# cumulative_flaring_co2                    0
# cumulative_gas_co2                        0
# cumulative_oil_co2                        0
# cumulative_other_co2                      0
# trade_co2_share                           0
# share_global_co2                          0
# share_global_cement_co2                   0
# share_global_coal_co2                     0
# share_global_flaring_co2                  0
# share_global_gas_co2                      0
# share_global_oil_co2                      0
# share_global_other_co2                    0
# share_global_cumulative_co2               0
# share_global_cumulative_cement_co2        0
# share_global_cumulative_coal_co2          0
# share_global_cumulative_flaring_co2       0
# share_global_cumulative_gas_co2           0
# share_global_cumulative_oil_co2           0
# share_global_cumulative_other_co2         0
# total_ghg                                 0
# ghg_per_capita                            0
# total_ghg_excluding_lucf                  0
# ghg_excluding_lucf_per_capita             0
# methane                                   0
# methane_per_capita                        0
# nitrous_oxide                             0
# nitrous_oxide_per_capita                  0
# population                                0
# gdp                                       0
# primary_energy_consumption                0
# energy_per_capita                         0
# energy_per_gdp                            0
# dtype: int64

# %% [markdown]
# # Utilizar o describe para determinar os dados estatisticos do dataframe.

# %%
df1.describe()
# Out:
#                year           co2  co2_per_capita     trade_co2    cement_co2  \
# count  14999.000000  14999.000000    14999.000000  14999.000000  14999.000000
# mean    1951.947196    307.504361        3.773238      2.134383     16.057141
# std       55.414106   1264.457642        7.183108    111.036797     49.494147
# min     1750.000000      0.000000        0.000000  -1657.998000      0.000000
# 25%     1923.000000      0.634000        0.297000      2.134383      0.699000
# 50%     1967.000000      6.925000        1.604000      2.134383     16.057141
# 75%     1994.000000     77.417500        4.027500      2.134383     16.057141
# max     2020.000000  20608.593000      246.408000   2047.575000   1315.197000
#
#        cement_co2_per_capita      coal_co2  coal_co2_per_capita   flaring_co2  \
# count           14999.000000  14999.000000         14999.000000  14999.000000
# mean                0.114725    211.722194             1.539818     15.312338
# std                 0.107755    593.341662             2.181518     13.560896
# min                 0.000000      0.000000             0.000000      0.000000
# 25%                 0.076000      1.177500             0.150000     15.312338
# 50%                 0.114725     48.507000             1.539818     15.312338
# 75%                 0.114725    211.722194             1.539818     15.312338
# max                 2.738000  11265.459000            34.184000    230.355000
#
#        flaring_co2_per_capita  ...  ghg_excluding_lucf_per_capita  \
# count            14999.000000  ...                   14999.000000
# mean                 0.552463  ...                       6.965232
# std                  1.420731  ...                       3.526881
# min                  0.000000  ...                       0.405000
# 25%                  0.552463  ...                       6.965232
# 50%                  0.552463  ...                       6.965232
# 75%                  0.552463  ...                       6.965232
# max                 59.830000  ...                      53.650000
#
#             methane  methane_per_capita  nitrous_oxide  \
# count  14999.000000        14999.000000   14999.000000
# mean      41.659193            2.108664      17.740256
# std       57.608938            1.922652      25.082230
# min        0.000000            0.000000       0.000000
# 25%       41.659193            2.108664      17.740256
# 50%       41.659193            2.108664      17.740256
# 75%       41.659193            2.108664      17.740256
# max     1242.430000           39.795000     547.290000
#
#        nitrous_oxide_per_capita    population           gdp  \
# count              14999.000000  1.499900e+04  1.499900e+04
# mean                   0.625127  6.368908e+07  2.212016e+11
# std                    0.461938  2.602731e+08  6.022665e+11
# min                    0.000000  7.129000e+03  5.543200e+07
# 25%                    0.625127  1.551556e+06  2.567668e+10
# 50%                    0.625127  5.994075e+06  2.212016e+11
# 75%                    0.625127  5.657534e+07  2.212016e+11
# max                   10.056000  4.639847e+09  1.815162e+13
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# count                14999.000000       14999.000000    14999.000000
# mean                   915.623530       22778.777337        1.633573
# std                   2040.527546       16729.846108        0.854711
# min                      0.040000          97.255000        0.078000
# 25%                    200.647000       22778.777337        1.633573
# 50%                    915.623530       22778.777337        1.633573
# 75%                    915.623530       22778.777337        1.633573
# max                  40404.443000      189841.170000       25.253000
#
# [8 rows x 58 columns]

# %% [markdown]
# # Criar um gráfico no seaborn para visualizar e analisar os dados do dataframe

# %%
sns.set(rc={'figure.figsize': (15,5)})
sns.histplot(data=df1,x='year', y='co2', binwidth=50)
# Out:
# <Axes: xlabel='year', ylabel='co2'>

# %% [markdown]
# # No gráfico anterior comparei a quantidade de co2 em uma escala de tempo.
